# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("CC GENERAL.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.MINIMUM_PAYMENTS = df.MINIMUM_PAYMENTS.fillna(df.MINIMUM_PAYMENTS.mean())
df.CREDIT_LIMIT = df.CREDIT_LIMIT.fillna(df.CREDIT_LIMIT.mean())

# %%
df = df.drop(['CUST_ID'], axis=1)

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
#scaling dataframe
df_scaled = std_scaler.fit_transform(df)

# %%
#Transforming the DataFrame into 2D DataFrame
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_ = pca.fit_transform(df_scaled)
pca_final = pd.DataFrame(data=pca_, columns=['component1', 'component2'])
pca_final
# Out:
#       component1  component2
# 0      -1.682219   -1.076452
# 1      -1.138293    2.506472
# 2       0.969679   -0.383517
# 3      -0.873624    0.043161
# 4      -1.599433   -0.688581
# ...          ...         ...
# 8945   -0.359629   -2.016145
# 8946   -0.564365   -1.639125
# 8947   -0.926202   -1.810786
# 8948   -2.336550   -0.657966
# 8949   -0.556426   -0.400462
#
# [8950 rows x 2 columns]

# %%
#Finding the optimal number of clusters to use in the K_Means algorithm
from sklearn.cluster import KMeans
intertia = []
range_ = range(1,10)
for i in range_:
    km = KMeans(n_clusters=i)
    km.fit_predict(pd.DataFrame(df_scaled))
    intertia.append(km.inertia_)
plt.plot(range_, intertia, 'rx-')
plt.xlabel('range')
plt.ylabel('distortion')
plt.show()

# %%
#number of clusters equals 4
#begin clustering
kmeans_model = KMeans(n_clusters=4, init='k-means++', random_state=0)
kmeans_model.fit_predict(df_scaled)
# Out:
# array([3, 1, 0, ..., 0, 3, 3])

# %%
pca_final_kmeans = pd.concat([pca_final, pd.DataFrame({'cluster':kmeans_model.labels_})], axis=1)

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x='component1', y='component2', hue='cluster', data=pca_final_kmeans, palette=['red', 'green', 'blue', 'yellow'])
plt.show()

# %%
#adding cluster column to DataFrame
cluster_df = pd.concat([df, pd.DataFrame({'cluster':kmeans_model.labels_})], axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
#Visualising cluster's count
sns.countplot(x='cluster', data=cluster_df)
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='count'>

# %%
#saving model
import joblib
joblib.dump(kmeans_model, 'kmeans_model.pkl')
# Out:
# ['kmeans_model.pkl']

# %%
#saving cluster_df csv file
cluster_df.to_csv('clustered_customers.csv')

# %%
#training and testing the kmeans_model
from sklearn.model_selection import train_test_split
X = cluster_df.drop(['cluster'], axis=1)
y = cluster_df.cluster
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
model_classifier = DecisionTreeClassifier(criterion='entropy')
model_classifier.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
print(type(test_X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
y_pred = model_classifier.predict(test_X)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(test_y, y_pred))
print(classification_report(test_y, y_pred))
# Out:
# [[623   3   4  24]
#  [  7 208   2  20]
#  [  6   0  68   0]
#  [ 21  12   0 792]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       654
#            1       0.93      0.88      0.90       237
#            2       0.92      0.92      0.92        74
#            3       0.95      0.96      0.95       825
#
#     accuracy                           0.94      1790
#    macro avg       0.94      0.93      0.93      1790
# weighted avg       0.94      0.94      0.94      1790

# %%
#saving the model
import pickle
filename = 'customer_classifier.sav'
pickle.dump(model_classifier, open(filename, 'wb'))

# %%
#load the model
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(test_X, test_y)
print(result)
# Out:
# 0.9446927374301676

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.0.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: d:\anaconda\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: scikit-learn-intelex
# Note: you may need to restart the kernel to use updated packages.
